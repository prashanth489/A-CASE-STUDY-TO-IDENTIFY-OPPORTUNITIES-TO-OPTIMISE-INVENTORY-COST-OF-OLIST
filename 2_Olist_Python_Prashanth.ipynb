# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

import squarify
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# #### Data Reading from the Excel Sheet

# %%
orders = pd.read_excel("Retail_dataset.xlsx", sheet_name="orders")
order_items = pd.read_excel("Retail_dataset.xlsx", sheet_name="order_items")
customers = pd.read_excel("Retail_dataset.xlsx", sheet_name="customers")
payments = pd.read_excel("Retail_dataset.xlsx", sheet_name="payments")
products = pd.read_excel("Retail_dataset.xlsx", sheet_name="products")
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_timestamp order_estimated_delivery_date
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2018-08-07 15:27:45                    2018-08-13
# 2       2018-08-17 18:06:29                    2018-09-04
# 3       2017-12-02 00:28:42                    2017-12-15
# 4       2018-02-16 18:17:02                    2018-02-26

# %%
orders.shape
# Out:
# (99441, 7)

# %%
# Unique "order_id"

orders.order_id.duplicated().sum()
# Out:
# 0

# %%
# finding Duplicate "customer_id"

orders.customer_id.duplicated().sum()
# Out:
# 3345

# %%
orders.customer_id.value_counts().sort_values(ascending=False).head(25)
# Out:
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 6469f99c1f9dfae7733b25662e7f1782     7
# ca77025e7201e3b30c44b472ff346268     7
# de34b16117594161a6a89c50b289d35a     6
# 47c1a3033b8b77b3ab6e109eb4d5fdf3     6
# 63cfc61cee11cbe306bff5857d00bfe4     6
# 12f5d6e1cbf93dafd9dcc19095df0b3d     6
# f0e310a6839dce9de1638e0fe5ab282a     6
# dc813062e0fc23409cd255f7f53c7074     6
# 4e65032f1f574189fb793bac5a867bbc     5
# 56c8638e7c058b98aae6d74d2dd6ea23     5
# 5e8f38a9a1c023f3db718edcf926a2db     5
# fe81bb32c243a86b2f86fbf053fe6140     5
# b4e4f24de1e8725b74e4a1f4975116ed     5
# 74cb1ad7e6d5674325c1f99b5ea30d82     5
# 35ecdf6858edc6427223b64804cf028e     5
# 394ac4de8f3acb14253c177f0e15bc58     5
# f34cd7fd85a1f8baff886edf09567be3     4
# 25a560b9a6006157838aab1bdbd68624     4
# a0abd26659c9914690cbd3320d39fd96     4
# 08e5b38d7948d37fbb2a59fc5e175ab1     4
# c8460e4251689ba205045f3ea17884a1     4
# a239b8e2fbce33780f1f1912e2ee5275     4
# Name: customer_id, dtype: int64

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_timestamp order_estimated_delivery_date
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2018-08-07 15:27:45                    2018-08-13
# 2       2018-08-17 18:06:29                    2018-09-04
# 3       2017-12-02 00:28:42                    2017-12-15
# 4       2018-02-16 18:17:02                    2018-02-26

# %%
orders.order_status.value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %%
#checking for percentage data frequency
orders.order_status.value_counts(normalize=True)*100
# Out:
# delivered      97.020344
# shipped         1.113223
# canceled        0.628513
# unavailable     0.612423
# invoiced        0.315765
# processing      0.302692
# created         0.005028
# approved        0.002011
# Name: order_status, dtype: float64

# %%
# finding null values
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_timestamp        2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# #### Since we are only interested in orders "delivered". Let's take the data to accomodate only 'delivered' orders.

# %%
orders = orders[orders.order_status == "delivered"]
orders.shape
# Out:
# (96478, 7)

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_timestamp order_estimated_delivery_date
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2018-08-07 15:27:45                    2018-08-13
# 2       2018-08-17 18:06:29                    2018-09-04
# 3       2017-12-02 00:28:42                    2017-12-15
# 4       2018-02-16 18:17:02                    2018-02-26

# %%
# finding missing values

orders.isna().sum().sort_values(ascending=False)
# Out:
# order_approved_at                14
# order_delivered_timestamp         8
# order_id                          0
# customer_id                       0
# order_status                      0
# order_purchase_timestamp          0
# order_estimated_delivery_date     0
# dtype: int64

# %% [markdown]
# #### Filling NaN values with calculated difference with the help of other fields

# %%
# we have taken median of differences between order_approved_at and order_purchased and then filled the nan values with sum of order_purchased and diff
diff = (orders['order_approved_at'] - orders['order_purchase_timestamp']).median()
orders['order_approved_at'].fillna(orders['order_purchase_timestamp'] + diff,inplace=True)
# we have taken median of differences between order_delivered_carrier_date and order_approved_at and then filled the nan values with sum of order_approved_at and diff
diff = (orders['order_delivered_timestamp'] - orders['order_approved_at']).median()
orders['order_delivered_timestamp'].fillna(orders['order_approved_at'] + diff,inplace=True)

# %%
# missing values check

orders.isna().sum().sort_values(ascending=False)
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_timestamp        0
# order_estimated_delivery_date    0
# dtype: int64

# %%
# duplicated values check
orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Order_items sheet.

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    shipping_charges
# 0             13.29
# 1             19.93
# 2             17.87
# 3             12.79
# 4             18.14

# %%
order_items.shape
# Out:
# (112650, 6)

# %%
order_items.isna().sum()
# Out:
# order_id            0
# order_item_id       0
# product_id          0
# seller_id           0
# price               0
# shipping_charges    0
# dtype: int64

# %% [markdown]
# #### Customers sheet.

# %%
customers.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3  259dac757896d24d7702b9acbbff3f3c                      8775
# 4  345ecd01c38d18a9036ed96c73b8d066                     13056
#
#            customer_city customer_state
# 0                 franca             SP
# 1  sao bernardo do campo             SP
# 2              sao paulo             SP
# 3        mogi das cruzes             SP
# 4               campinas             SP

# %%
customers.shape
# Out:
# (99441, 4)

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.customer_id.duplicated().sum()
# Out:
# 3345

# %%
customers[customers.customer_id.duplicated()]
# Out:
#                             customer_id  customer_zip_code_prefix  \
# 679    b6c083700ca8c135ba9f0f132930d4e8                      8686
# 1463   a40096fc0a3862e9e12bc55b5f8e6ab2                     20561
# 1607   b8b3c435a58aebd788a477bed8342910                     95585
# 2811   66980c3775537536f77b434d74e520f5                     30290
# 3198   788313d21c3507fe890921f6e17aa679                     11070
# ...                                 ...                       ...
# 99324  8bab3162259edfaadd1ea2e1fe7f58dc                     31565
# 99327  12ab9334b1240d6d037f2b0102a49571                     38050
# 99336  0ee57f62666561b72f2ceacad0230cbf                      9530
# 99353  0ceb502fc33a2ad327b08288c5310e2e                     29134
# 99406  5cbfdb85ec130898108b32c50d619c39                     74980
#
#               customer_city customer_state
# 679                  suzano             SP
# 1463         rio de janeiro             RJ
# 1607          arroio do sal             RS
# 2811         belo horizonte             MG
# 3198                 santos             SP
# ...                     ...            ...
# 99324        belo horizonte             MG
# 99327               uberaba             MG
# 99336    sao caetano do sul             SP
# 99353                 viana             ES
# 99406  aparecida de goiania             GO
#
# [3345 rows x 4 columns]

# %%
customers[customers.customer_id.duplicated()].shape
# Out:
# (3345, 4)

# %%
customers.shape
# Out:
# (99441, 4)

# %%
customers.drop_duplicates(subset="customer_id", keep="first")
# Out:
#                             customer_id  customer_zip_code_prefix  \
# 0      861eff4711a542e4b93843c6dd7febb0                     14409
# 1      290c77bc529b7ac935b93aa66c333dc3                      9790
# 2      060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3      259dac757896d24d7702b9acbbff3f3c                      8775
# 4      345ecd01c38d18a9036ed96c73b8d066                     13056
# ...                                 ...                       ...
# 99436  1a29b476fee25c95fbafc67c5ac95cf8                      3937
# 99437  d52a67c98be1cf6a5c84435bd38d095d                      6764
# 99438  e9f50caf99f032f0bf3c55141f019d99                     60115
# 99439  73c2643a0a458b49f58cea58833b192e                     92120
# 99440  84732c5050c01db9b23e19ba39899398                      6703
#
#                customer_city customer_state
# 0                     franca             SP
# 1      sao bernardo do campo             SP
# 2                  sao paulo             SP
# 3            mogi das cruzes             SP
# 4                   campinas             SP
# ...                      ...            ...
# 99436              sao paulo             SP
# 99437        taboao da serra             SP
# 99438              fortaleza             CE
# 99439                 canoas             RS
# 99440                  cotia             SP
#
# [96096 rows x 4 columns]

# %%
customers.drop_duplicates(subset="customer_id", keep="first", inplace=True)

# %%
customers.shape
# Out:
# (96096, 4)

# %%
customers.customer_id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Payments sheet.

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
payments.shape
# Out:
# (103886, 5)

# %%
payments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# ##### Products sheet.

# %%
products.shape
# Out:
# (32951, 6)

# %%
products.head()
# Out:
#                          product_id product_category_name  product_weight_g  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumery             225.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   art            1000.0
# 2  96bd76ec8810374ed1b65e291975717f        sports_leisure             154.0
# 3  cef67bcfe19066a932b7673e239eb23d                  baby             371.0
# 4  9dc1a7de274444849c219cff195d0b71            housewares             625.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               16.0               10.0              14.0
# 1               30.0               18.0              20.0
# 2               18.0                9.0              15.0
# 3               26.0                4.0              26.0
# 4               20.0               17.0              13.0

# %%
products.isna().sum().sort_values(ascending=False)
# Out:
# product_category_name    170
# product_weight_g           2
# product_length_cm          2
# product_height_cm          2
# product_width_cm           2
# product_id                 0
# dtype: int64

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   product_category_name  32781 non-null  object
#  2   product_weight_g       32949 non-null  float64
#  3   product_length_cm      32949 non-null  float64
#  4   product_height_cm      32949 non-null  float64
#  5   product_width_cm       32949 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 1.5+ MB

# %%
products.product_category_name.value_counts()
# Out:
# toys                                 24725
# bed_bath_table                         789
# sports_leisure                         721
# furniture_decor                        687
# health_beauty                          648
#                                      ...
# fashion_childrens_clothes                1
# diapers_and_hygiene                      1
# home_comfort_2                           1
# security_and_services                    1
# furniture_mattress_and_upholstery        1
# Name: product_category_name, Length: 70, dtype: int64

# %%
products.product_category_name.value_counts(normalize=True)*100
# Out:
# toys                                 75.424789
# bed_bath_table                        2.406882
# sports_leisure                        2.199445
# furniture_decor                       2.095726
# health_beauty                         1.976755
#                                        ...
# fashion_childrens_clothes             0.003051
# diapers_and_hygiene                   0.003051
# home_comfort_2                        0.003051
# security_and_services                 0.003051
# furniture_mattress_and_upholstery     0.003051
# Name: product_category_name, Length: 70, dtype: float64

# %%
products.product_category_name.mode()[0]
# Out:
# 'toys'

# %%
# Filling the missing number of product categories with 'Toys' as it is the most occuring product category.

# %%
products.product_category_name.fillna(products.product_category_name.mode()[0], inplace=True)

# %%
products.isna().sum().sort_values(ascending=False)
# Out:
# product_weight_g         2
# product_length_cm        2
# product_height_cm        2
# product_width_cm         2
# product_id               0
# product_category_name    0
# dtype: int64

# %%
products.isna().sum()
# Out:
# product_id               0
# product_category_name    0
# product_weight_g         2
# product_length_cm        2
# product_height_cm        2
# product_width_cm         2
# dtype: int64

# %%
products.describe()
# Out:
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
num_cols = products.describe().columns.to_list()
num_cols
# Out:
# ['product_weight_g',
#  'product_length_cm',
#  'product_height_cm',
#  'product_width_cm']

# %%
for i in num_cols:
    plt.figure(figsize=(12,5))
    sns.distplot(products[i])
    plt.axvline(products[i].mean(), color="red")
    plt.axvline(products[i].median(), color="green")
    plt.show()
    print("="*90)
# Out:
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================

# %%
plt.figure(figsize=(12,5))
sns.distplot(products.product_weight_g)
plt.axvline(products.product_weight_g.mean(), color="red")
plt.axvline(products.product_weight_g.median(), color="green")
plt.show()

# %%
for i in num_cols:
    plt.figure(figsize=(12,5))
    sns.boxplot(products[i])
    plt.show()
    print("="*90)
# Out:
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================
# ==========================================================================================

# %%
for i in num_cols:
    products[i].fillna(products[i].median(), inplace=True)

# %%
products.isna().sum().sort_values(ascending=False)
# Out:
# product_id               0
# product_category_name    0
# product_weight_g         0
# product_length_cm        0
# product_height_cm        0
# product_width_cm         0
# dtype: int64

# %%
#writer = pd.ExcelWriter('New_Retail_dataset.xlsx', engine='xlsxwriter')

# %%
'''# Write each dataframe to a different worksheet.
orders.to_excel(writer, sheet_name='orders')
order_items.to_excel(writer, sheet_name='order_items')
customers.to_excel(writer, sheet_name='customers')
products.to_excel(writer, sheet_name='products')
payments.to_excel(writer, sheet_name='payments')
'''
# Out:
# "# Write each dataframe to a different worksheet.\norders.to_excel(writer, sheet_name='orders')\norder_items.to_excel(writer, sheet_name='order_items')\ncustomers.to_excel(writer, sheet_name='customers')\nproducts.to_excel(writer, sheet_name='products')\npayments.to_excel(writer, sheet_name='payments')\n"

# %%
'''# Close the Pandas Excel writer and output the Excel file.
writer.save()'''
# Out:
# '# Close the Pandas Excel writer and output the Excel file.\nwriter.save()'

# %% [markdown]
# ### Merging DataFrames

# %%
ord_prod =pd.merge(order_items, products, on="product_id", how="inner")
ord_prod.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3  6f8c31653edb8c83e1a739408b5ff750              1
# 4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id                         seller_id  price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   55.9
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   64.9
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
#
#    shipping_charges product_category_name  product_weight_g  \
# 0             13.29                  toys             650.0
# 1             17.96                  toys             650.0
# 2             18.33                  toys             650.0
# 3             16.17                  toys             650.0
# 4             13.29                  toys             650.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               28.0                9.0              14.0
# 1               28.0                9.0              14.0
# 2               28.0                9.0              14.0
# 3               28.0                9.0              14.0
# 4               28.0                9.0              14.0

# %%
cust_ord =pd.merge(orders, customers, on="customer_id", how="inner")
cust_ord.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  69923a4e07ce446644394df37a710286  7c396fd4830fd04220f754e42b4e5bff
# 2  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 3  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 4  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-09-04 11:26:38 2017-09-04 11:43:25
# 2    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 3    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 4    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
#
#   order_delivered_timestamp order_estimated_delivery_date  \
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2017-09-05 19:20:20                    2017-09-15
# 2       2018-08-07 15:27:45                    2018-08-13
# 3       2018-08-17 18:06:29                    2018-09-04
# 4       2017-12-02 00:28:42                    2017-12-15
#
#    customer_zip_code_prefix            customer_city customer_state
# 0                      3149                sao paulo             SP
# 1                      3149                sao paulo             SP
# 2                     47813                barreiras             BA
# 3                     75265               vianopolis             GO
# 4                     59296  sao goncalo do amarante             RN

# %%
ord_pay = pd.merge(cust_ord, payments, on="order_id", how="inner")
ord_pay.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 2  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 3  69923a4e07ce446644394df37a710286  7c396fd4830fd04220f754e42b4e5bff
# 4  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2017-09-04 11:26:38 2017-09-04 11:43:25
# 4    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
#
#   order_delivered_timestamp order_estimated_delivery_date  \
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2017-10-10 21:25:13                    2017-10-18
# 2       2017-10-10 21:25:13                    2017-10-18
# 3       2017-09-05 19:20:20                    2017-09-15
# 4       2018-08-07 15:27:45                    2018-08-13
#
#    customer_zip_code_prefix customer_city customer_state  payment_sequential  \
# 0                      3149     sao paulo             SP                   1
# 1                      3149     sao paulo             SP                   3
# 2                      3149     sao paulo             SP                   2
# 3                      3149     sao paulo             SP                   1
# 4                     47813     barreiras             BA                   1
#
#   payment_type  payment_installments  payment_value
# 0  credit_card                     1          18.12
# 1      voucher                     1           2.00
# 2      voucher                     1          18.59
# 3  credit_card                     1          44.11
# 4       wallet                     1         141.46

# %%
ord_final = pd.merge(ord_pay, ord_prod, on="order_id", how="inner")
ord_final.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 2  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 3  69923a4e07ce446644394df37a710286  7c396fd4830fd04220f754e42b4e5bff
# 4  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2017-09-04 11:26:38 2017-09-04 11:43:25
# 4    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
#
#   order_delivered_timestamp order_estimated_delivery_date  \
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2017-10-10 21:25:13                    2017-10-18
# 2       2017-10-10 21:25:13                    2017-10-18
# 3       2017-09-05 19:20:20                    2017-09-15
# 4       2018-08-07 15:27:45                    2018-08-13
#
#    customer_zip_code_prefix customer_city customer_state  ...  order_item_id  \
# 0                      3149     sao paulo             SP  ...              1
# 1                      3149     sao paulo             SP  ...              1
# 2                      3149     sao paulo             SP  ...              1
# 3                      3149     sao paulo             SP  ...              1
# 4                     47813     barreiras             BA  ...              1
#
#                          product_id                         seller_id   price  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# 2  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# 3  9abb00920aae319ef9eba674b7d2e6ff  1771297ac436903d1dd6b0e9279aa505   35.39
# 4  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962  118.70
#
#    shipping_charges product_category_name product_weight_g  product_length_cm  \
# 0              8.72            housewares            500.0               19.0
# 1              8.72            housewares            500.0               19.0
# 2              8.72            housewares            500.0               19.0
# 3              8.72                  baby            350.0               19.0
# 4             22.76                  toys            400.0               19.0
#
#    product_height_cm product_width_cm
# 0                8.0             13.0
# 1                8.0             13.0
# 2                8.0             13.0
# 3               14.0             12.0
# 4               13.0             19.0
#
# [5 rows x 24 columns]

# %%
ord_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115035 entries, 0 to 115034
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115035 non-null  object
#  1   customer_id                    115035 non-null  object
#  2   order_status                   115035 non-null  object
#  3   order_purchase_timestamp       115035 non-null  datetime64[ns]
#  4   order_approved_at              115035 non-null  datetime64[ns]
#  5   order_delivered_timestamp      115035 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  115035 non-null  datetime64[ns]
#  7   customer_zip_code_prefix       115035 non-null  int64
#  8   customer_city                  115035 non-null  object
#  9   customer_state                 115035 non-null  object
#  10  payment_sequential             115035 non-null  int64
#  11  payment_type                   115035 non-null  object
#  12  payment_installments           115035 non-null  int64
#  13  payment_value                  115035 non-null  float64
#  14  order_item_id                  115035 non-null  int64
#  15  product_id                     115035 non-null  object
#  16  seller_id                      115035 non-null  object
#  17  price                          115035 non-null  float64
#  18  shipping_charges               115035 non-null  float64
#  19  product_category_name          115035 non-null  object
#  20  product_weight_g               115035 non-null  float64
#  21  product_length_cm              115035 non-null  float64
#  22  product_height_cm              115035 non-null  float64
#  23  product_width_cm               115035 non-null  float64
# dtypes: datetime64[ns](4), float64(7), int64(4), object(9)
# memory usage: 21.9+ MB

# %%
ord_final.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_timestamp        0
# order_estimated_delivery_date    0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# price                            0
# shipping_charges                 0
# product_category_name            0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# dtype: int64

# %%
# Most number of products delivered
ord_final.product_category_name.value_counts().nlargest(10)
# Out:
# toys                     86777
# health_beauty             3047
# bed_bath_table            2690
# sports_leisure            2332
# computers_accessories     2209
# furniture_decor           2193
# housewares                1718
# watches_gifts             1555
# telephony                 1229
# auto                      1076
# Name: product_category_name, dtype: int64

# %%
#%matplotlib inline 
sns.set(color_codes=True)
b=ord_final.product_category_name.value_counts().nlargest(20)


# Checking most ordered product
ord_final.product_category_name.value_counts().nlargest(20).plot(kind='bar', figsize=(10,5))
plt.title("TOP 20 most number of product delivered")
plt.ylabel('Count')
plt.xlabel('Category');
b
# Out:
# toys                               86777
# health_beauty                       3047
# bed_bath_table                      2690
# sports_leisure                      2332
# computers_accessories               2209
# furniture_decor                     2193
# housewares                          1718
# watches_gifts                       1555
# telephony                           1229
# auto                                1076
# garden_tools                        1070
# cool_stuff                          1020
# perfumery                            856
# baby                                 788
# electronics                          722
# office_furniture                     702
# stationery                           638
# pet_shop                             513
# fashion_bags_accessories             445
# construction_tools_construction      254
# Name: product_category_name, dtype: int64

# %% [markdown]
# We can see that the most frequent purchases from a product category are in the following order:
# 1. Toys
# 2. Health and Beauty
# 3. Bed Bath Table
# 4. Sports and Leisure
# 5. Computer Accessories

# %%
#most number of product ordered vs revenue
prod_rev=ord_final.groupby(by=["product_category_name"])["price"].sum()

# %%
# Top 20 revenue genrating products
a=pd.DataFrame(prod_rev.nlargest(20)).reset_index()
prod_rev.nlargest(20).plot(kind='bar', figsize=(10,5))
plt.title("TOP 20 revenue generator")
plt.ylabel('Revenue In M')
plt.xlabel('Category');

a.product_category_name
# Out:
# 0                      toys
# 1             health_beauty
# 2             watches_gifts
# 3            sports_leisure
# 4     computers_accessories
# 5            bed_bath_table
# 6                cool_stuff
# 7           furniture_decor
# 8                housewares
# 9                      auto
# 10         office_furniture
# 11             garden_tools
# 12                     baby
# 13                perfumery
# 14                telephony
# 15                 pet_shop
# 16               stationery
# 17                computers
# 18         small_appliances
# 19        home_appliances_2
# Name: product_category_name, dtype: object

# %% [markdown]
# Toys, health_beauty and watches_gift make up more than 80% of all revenue

# %%
sns.heatmap(ord_pay.corr(),annot=True)
plt.show()
# Out:
# /Users/savprasadarao/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:302: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
# /Users/savprasadarao/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:312: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = ax.figure.colorbar(mesh, cax, ax, **self.cbar_kws)

# %% [markdown]
# ### RFM Modelling:

# %% [markdown]
# We need to create 3 freatures from the data:
#
# 1. Recency: Latest date- last purchase date
# 2. Frequency: Total no. of transactions made by a single customer (count of order id)
# 3. Monetary: Total value of transacted sales by each customer.

# %% [markdown]
# ##### Calculating  Recency

# %%
#finding the last date on which a customer made purchase
recency=pd.DataFrame(ord_final.groupby('product_id')['order_purchase_timestamp'].max().reset_index())

# %%
recency['order_purchase_timestamp'].max()
# Out:
# Timestamp('2018-08-29 15:00:37')

# %%
# Calculating recency using maximum date of purchase made by a customer as the date to calculate the recency of purchases
recency['recent_days']=(recency['order_purchase_timestamp'].max()-recency['order_purchase_timestamp']).dt.days
recency
# Out:
#                              product_id order_purchase_timestamp  recent_days
# 0      00066f42aeeb9f3007548bb9d3f33c38      2018-05-20 18:45:21          100
# 1      00088930e925c41fd95ebfe695fd2655      2017-12-12 19:20:28          259
# 2      0009406fd7479715e4bef61dd91f2462      2017-12-21 16:21:47          250
# 3      000b8f95fcb9e0096488278317764d19      2018-08-10 13:24:35           19
# 4      000d9be29b5207b54e86aa1b1ac54872      2018-04-03 09:24:12          148
# ...                                 ...                      ...          ...
# 32211  fff6177642830a9a94a0f2cba5e476d1      2017-09-03 11:38:54          360
# 32212  fff81cc3158d2725c0655ab9ba0f712c      2018-07-30 09:18:59           30
# 32213  fff9553ac224cec9d15d49f5a263411f      2017-10-06 16:44:05          326
# 32214  fffdb2d0ec8d6a61f0a0a0db3f25b441      2018-08-10 17:15:07           18
# 32215  fffe9eeff12fcbd74a2f2b007dde0c58      2018-05-16 17:44:30          104
#
# [32216 rows x 3 columns]

# %% [markdown]
# ##### Calculating Frequency

# %% [markdown]
# We will count the number of unique orders made by each customer to obtain their purchase frequencies.

# %%
frequency=pd.DataFrame(ord_final.groupby('product_id')['customer_id'].count().reset_index())
frequency
# Out:
#                              product_id  customer_id
# 0      00066f42aeeb9f3007548bb9d3f33c38            1
# 1      00088930e925c41fd95ebfe695fd2655            1
# 2      0009406fd7479715e4bef61dd91f2462            1
# 3      000b8f95fcb9e0096488278317764d19            2
# 4      000d9be29b5207b54e86aa1b1ac54872            1
# ...                                 ...          ...
# 32211  fff6177642830a9a94a0f2cba5e476d1            2
# 32212  fff81cc3158d2725c0655ab9ba0f712c            1
# 32213  fff9553ac224cec9d15d49f5a263411f            1
# 32214  fffdb2d0ec8d6a61f0a0a0db3f25b441            5
# 32215  fffe9eeff12fcbd74a2f2b007dde0c58            1
#
# [32216 rows x 2 columns]

# %% [markdown]
# ##### Calculating Monetary

# %%
monetary=pd.DataFrame(ord_final[['product_id','payment_value']].groupby('product_id')['payment_value'].sum().reset_index())
monetary
# Out:
#                              product_id  payment_value
# 0      00066f42aeeb9f3007548bb9d3f33c38         120.24
# 1      00088930e925c41fd95ebfe695fd2655         143.83
# 2      0009406fd7479715e4bef61dd91f2462         242.10
# 3      000b8f95fcb9e0096488278317764d19         157.00
# 4      000d9be29b5207b54e86aa1b1ac54872         218.27
# ...                                 ...            ...
# 32211  fff6177642830a9a94a0f2cba5e476d1         285.39
# 32212  fff81cc3158d2725c0655ab9ba0f712c          97.89
# 32213  fff9553ac224cec9d15d49f5a263411f          43.85
# 32214  fffdb2d0ec8d6a61f0a0a0db3f25b441         228.82
# 32215  fffe9eeff12fcbd74a2f2b007dde0c58         303.87
#
# [32216 rows x 2 columns]

# %%
# Merging recency,frequency and monetary dataframe
df_rfm=pd.merge(recency,frequency,on='product_id')
df_rfm=pd.merge(df_rfm,monetary,on='product_id')
df_rfm
# Out:
#                              product_id order_purchase_timestamp  recent_days  \
# 0      00066f42aeeb9f3007548bb9d3f33c38      2018-05-20 18:45:21          100
# 1      00088930e925c41fd95ebfe695fd2655      2017-12-12 19:20:28          259
# 2      0009406fd7479715e4bef61dd91f2462      2017-12-21 16:21:47          250
# 3      000b8f95fcb9e0096488278317764d19      2018-08-10 13:24:35           19
# 4      000d9be29b5207b54e86aa1b1ac54872      2018-04-03 09:24:12          148
# ...                                 ...                      ...          ...
# 32211  fff6177642830a9a94a0f2cba5e476d1      2017-09-03 11:38:54          360
# 32212  fff81cc3158d2725c0655ab9ba0f712c      2018-07-30 09:18:59           30
# 32213  fff9553ac224cec9d15d49f5a263411f      2017-10-06 16:44:05          326
# 32214  fffdb2d0ec8d6a61f0a0a0db3f25b441      2018-08-10 17:15:07           18
# 32215  fffe9eeff12fcbd74a2f2b007dde0c58      2018-05-16 17:44:30          104
#
#        customer_id  payment_value
# 0                1         120.24
# 1                1         143.83
# 2                1         242.10
# 3                2         157.00
# 4                1         218.27
# ...            ...            ...
# 32211            2         285.39
# 32212            1          97.89
# 32213            1          43.85
# 32214            5         228.82
# 32215            1         303.87
#
# [32216 rows x 5 columns]

# %%
#dropping unneccesary column
df_rfm.drop(['order_purchase_timestamp'],axis=1,inplace=True)
df_rfm
# Out:
#                              product_id  recent_days  customer_id  \
# 0      00066f42aeeb9f3007548bb9d3f33c38          100            1
# 1      00088930e925c41fd95ebfe695fd2655          259            1
# 2      0009406fd7479715e4bef61dd91f2462          250            1
# 3      000b8f95fcb9e0096488278317764d19           19            2
# 4      000d9be29b5207b54e86aa1b1ac54872          148            1
# ...                                 ...          ...          ...
# 32211  fff6177642830a9a94a0f2cba5e476d1          360            2
# 32212  fff81cc3158d2725c0655ab9ba0f712c           30            1
# 32213  fff9553ac224cec9d15d49f5a263411f          326            1
# 32214  fffdb2d0ec8d6a61f0a0a0db3f25b441           18            5
# 32215  fffe9eeff12fcbd74a2f2b007dde0c58          104            1
#
#        payment_value
# 0             120.24
# 1             143.83
# 2             242.10
# 3             157.00
# 4             218.27
# ...              ...
# 32211         285.39
# 32212          97.89
# 32213          43.85
# 32214         228.82
# 32215         303.87
#
# [32216 rows x 4 columns]

# %%
# Recency= Days from last purchase
#Frequency= Number of purchase made
#Monetary= total amount purchased by a customer
df_rfm.columns=['product_id','Recency','Frequency','Monetary']
df_rfm.reset_index()
df_rfm.set_index("product_id",inplace=True)

# %%
df_rfm
# Out:
#                                   Recency  Frequency  Monetary
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38      100          1    120.24
# 00088930e925c41fd95ebfe695fd2655      259          1    143.83
# 0009406fd7479715e4bef61dd91f2462      250          1    242.10
# 000b8f95fcb9e0096488278317764d19       19          2    157.00
# 000d9be29b5207b54e86aa1b1ac54872      148          1    218.27
# ...                                   ...        ...       ...
# fff6177642830a9a94a0f2cba5e476d1      360          2    285.39
# fff81cc3158d2725c0655ab9ba0f712c       30          1     97.89
# fff9553ac224cec9d15d49f5a263411f      326          1     43.85
# fffdb2d0ec8d6a61f0a0a0db3f25b441       18          5    228.82
# fffe9eeff12fcbd74a2f2b007dde0c58      104          1    303.87
#
# [32216 rows x 3 columns]

# %%
#descriptive stats for the RFM analysis
df_rfm.describe()
# Out:
#             Recency     Frequency       Monetary
# count  32216.000000  32216.000000   32216.000000
# mean     205.558884      3.570741     613.861449
# std      159.211091     10.971294    2163.471674
# min        0.000000      1.000000       9.590000
# 25%       67.000000      1.000000      91.787500
# 50%      174.000000      1.000000     198.260000
# 75%      312.000000      3.000000     477.425000
# max      695.000000    529.000000  109312.640000

# %%
df_rfm_log = df_rfm.copy()
print(df_rfm_log.describe())
# Out:
#             Recency     Frequency       Monetary
# count  32216.000000  32216.000000   32216.000000
# mean     205.558884      3.570741     613.861449
# std      159.211091     10.971294    2163.471674
# min        0.000000      1.000000       9.590000
# 25%       67.000000      1.000000      91.787500
# 50%      174.000000      1.000000     198.260000
# 75%      312.000000      3.000000     477.425000
# max      695.000000    529.000000  109312.640000

# %%
wcss = []
for i in range(1, 10):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df_rfm_log)
    wcss.append(kmeans.inertia_)

f, ax = plt.subplots(figsize=(15, 8))  
plt.style.use('_classic_test_patch')  
plt.plot(range(1, 10), wcss, '-*')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS');

# %% [markdown]
# #### Observation:
#
# We can see there is a sharp turn from the 4 point. We can select values between 4 to 6 for our clusters.
#
# Lets plot all the clusters 4, 5 & 6 to see which is defined better.

# %%
(df_rfm[df_rfm["Frequency"]>1].shape[0]/32216)*100
# Out:
# 47.04805065805811

# %% [markdown]
# #### From this above calculation we can say that around 47% customers are one time customers and only 53% are recurring customers.

# %%
#plot RFM distribution
plt.figure(figsize=(20,20))
#plot distribution of Recency
plt.subplot(3,1,1);
sns.distplot(df_rfm["Recency"])

#plot distribution of Frequency
plt.subplot(3,1,2);
sns.distplot(df_rfm["Frequency"])

#plot distribution of Monetary
plt.subplot(3,1,3);
sns.distplot(df_rfm["Monetary"])
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=1) 
kmeans.fit(df_rfm_log)
cluster_labels = kmeans.labels_
data_rfm_k4 = df_rfm_log.assign(Cluster=cluster_labels)
grouped = data_rfm_k4.groupby(['Cluster'])
grouped.agg({'Recency': 'mean','Frequency': 'mean','Monetary': ['mean', 'count']}).round(1)
# Out:
#         Recency Frequency Monetary
#            mean      mean     mean  count
# Cluster
# 0         209.1       2.5    342.9  30776
# 1          96.4      68.1  17297.7    144
# 2          82.8     226.3  58130.6     21
# 3         134.1      18.2   4322.3   1275

# %%
data_melt = pd.melt(
                    data_rfm_k4.reset_index(),               
                    id_vars=['product_id', 'Cluster'],
                    value_vars=['Recency', 'Frequency', 'Monetary'], 
                    var_name='Metric', value_name='Value'
                    )
data_melt.head(10)
# Out:
#                          product_id  Cluster   Metric  Value
# 0  00066f42aeeb9f3007548bb9d3f33c38        0  Recency  100.0
# 1  00088930e925c41fd95ebfe695fd2655        0  Recency  259.0
# 2  0009406fd7479715e4bef61dd91f2462        0  Recency  250.0
# 3  000b8f95fcb9e0096488278317764d19        0  Recency   19.0
# 4  000d9be29b5207b54e86aa1b1ac54872        0  Recency  148.0
# 5  0011c512eb256aa0dbbb544d8dffcf6e        0  Recency  257.0
# 6  00126f27c813603687e6ce486d909d01        0  Recency  345.0
# 7  001795ec6f1b187d37335e1c4704762e        0  Recency  245.0
# 8  001b237c0e9bb435f2e54071129237e9        0  Recency   20.0
# 9  001b72dfd63e9833e8c02742adf472e3        0  Recency  259.0

# %% [markdown]
# #### RFM Quartiles

# %% [markdown]
# The simples way to create product segments from RFM model is to use quartiles.We assign score from 1 to 4 to Recency,Frequency and Monetary.4 is the best/heighest value, and 1 is the lowest/worst value. A RFM score is calculated simply by combining individual RFM score numbers.

# %%
quantiles=df_rfm.quantile(q=[0.25,0.5,0.75])
quantiles.to_dict()
# Out:
# {'Recency': {0.25: 67.0, 0.5: 174.0, 0.75: 312.0},
#  'Frequency': {0.25: 1.0, 0.5: 1.0, 0.75: 3.0},
#  'Monetary': {0.25: 91.78750000000001, 0.5: 198.26, 0.75: 477.425}}

# %%
#x=value, p=recency,frequency, monetary_value,  d=quartiles dict
def RScore(x,p,d):
    if x<=d[p][0.25]:
        return 4
    elif x<= d[p][0.50]:
        return 3
    elif x<= d[p][0.75]:
        return 2
    else:
        return 1

# x=value, p=recency,frequency, monetary_value,  k=quartiles dict
def FMScore(x,p,k):
    if x<=k[p][0.25]:
        return 1
    elif x<=k[p][0.50]:
        return 2
    elif x<=k[p][0.75]:
        return 3
    else:
        return 4

# %%
#create RFM segmentation table
rfm_segmentation=df_rfm
rfm_segmentation['R_Quartile']=rfm_segmentation["Recency"].apply(RScore,args=('Recency',quantiles))
rfm_segmentation['F_Quartile']=rfm_segmentation["Frequency"].apply(FMScore,args=('Frequency',quantiles))
rfm_segmentation['M_Quartile']=rfm_segmentation["Monetary"].apply(FMScore,args=('Monetary',quantiles))

# %%
rfm_segmentation
# Out:
#                                   Recency  Frequency  Monetary  R_Quartile  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38      100          1    120.24           3
# 00088930e925c41fd95ebfe695fd2655      259          1    143.83           2
# 0009406fd7479715e4bef61dd91f2462      250          1    242.10           2
# 000b8f95fcb9e0096488278317764d19       19          2    157.00           4
# 000d9be29b5207b54e86aa1b1ac54872      148          1    218.27           3
# ...                                   ...        ...       ...         ...
# fff6177642830a9a94a0f2cba5e476d1      360          2    285.39           1
# fff81cc3158d2725c0655ab9ba0f712c       30          1     97.89           4
# fff9553ac224cec9d15d49f5a263411f      326          1     43.85           1
# fffdb2d0ec8d6a61f0a0a0db3f25b441       18          5    228.82           4
# fffe9eeff12fcbd74a2f2b007dde0c58      104          1    303.87           3
#
#                                   F_Quartile  M_Quartile
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38           1           2
# 00088930e925c41fd95ebfe695fd2655           1           2
# 0009406fd7479715e4bef61dd91f2462           1           3
# 000b8f95fcb9e0096488278317764d19           3           2
# 000d9be29b5207b54e86aa1b1ac54872           1           3
# ...                                      ...         ...
# fff6177642830a9a94a0f2cba5e476d1           3           3
# fff81cc3158d2725c0655ab9ba0f712c           1           2
# fff9553ac224cec9d15d49f5a263411f           1           1
# fffdb2d0ec8d6a61f0a0a0db3f25b441           4           3
# fffe9eeff12fcbd74a2f2b007dde0c58           1           3
#
# [32216 rows x 6 columns]

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.boxplot(data=df_rfm['Recency'])
plt.title('Recency')
plt.ylabel('Number of Compress')
plt.subplot(1,3,2)
sns.boxplot(data=df_rfm['Frequency'])
plt.title('Frequency')
plt.ylabel('Number of Compress')
plt.subplot(1,3,3)
sns.boxplot(data=df_rfm['Monetary'])
plt.title('Monetary')
plt.ylabel('Total Values')
plt.show()

# %%
rfm_segmentation['RFMScore']=rfm_segmentation.R_Quartile.map(str)+rfm_segmentation.F_Quartile.map(str)+rfm_segmentation.M_Quartile.map(str)
rfm_segmentation
# Out:
#                                   Recency  Frequency  Monetary  R_Quartile  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38      100          1    120.24           3
# 00088930e925c41fd95ebfe695fd2655      259          1    143.83           2
# 0009406fd7479715e4bef61dd91f2462      250          1    242.10           2
# 000b8f95fcb9e0096488278317764d19       19          2    157.00           4
# 000d9be29b5207b54e86aa1b1ac54872      148          1    218.27           3
# ...                                   ...        ...       ...         ...
# fff6177642830a9a94a0f2cba5e476d1      360          2    285.39           1
# fff81cc3158d2725c0655ab9ba0f712c       30          1     97.89           4
# fff9553ac224cec9d15d49f5a263411f      326          1     43.85           1
# fffdb2d0ec8d6a61f0a0a0db3f25b441       18          5    228.82           4
# fffe9eeff12fcbd74a2f2b007dde0c58      104          1    303.87           3
#
#                                   F_Quartile  M_Quartile RFMScore
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38           1           2      312
# 00088930e925c41fd95ebfe695fd2655           1           2      212
# 0009406fd7479715e4bef61dd91f2462           1           3      213
# 000b8f95fcb9e0096488278317764d19           3           2      432
# 000d9be29b5207b54e86aa1b1ac54872           1           3      313
# ...                                      ...         ...      ...
# fff6177642830a9a94a0f2cba5e476d1           3           3      133
# fff81cc3158d2725c0655ab9ba0f712c           1           2      412
# fff9553ac224cec9d15d49f5a263411f           1           1      111
# fffdb2d0ec8d6a61f0a0a0db3f25b441           4           3      443
# fffe9eeff12fcbd74a2f2b007dde0c58           1           3      313
#
# [32216 rows x 7 columns]

# %%
def segment(x):
    if x in ['444','443','433','442','434']:
        return 'Superhit Products'
    elif x in [ '432','341','342','332','333','344','343','441']:
        return 'Fast Moving Average Price Products '
    elif x in ['334', '234','214','224','413','314','244','243']:
        return 'Costly Products'
    elif x in ['212', '213', '222','211','114','311','312','214','143','142','141','241']:
        return 'Infrequent Products'
    elif x in ['111', '121','112','113','144']:
        return 'Hardly Any Sale Products'
    else:
        return 'Average Sale Products'

# %%
rfm_segmentation['segments'] = rfm_segmentation['RFMScore'].apply(segment)
rfm_segmentation['segments'].value_counts()
# Out:
# Average Sale Products                  7850
# Infrequent Products                    7602
# Hardly Any Sale Products               5398
# Fast Moving Average Price Products     3880
# Superhit Products                      3804
# Costly Products                        3682
# Name: segments, dtype: int64

# %%
segmentwise = rfm_segmentation.groupby('segments').agg(RecencyMean = ('Recency', 'mean'),
                                          FrequencyMean = ('Frequency', 'mean'),
                                          MonetaryMean = ('Monetary', 'mean'),
                                          GroupSize = ('Recency', 'size'))
segmentwise
# Out:
#                                      RecencyMean  FrequencyMean  MonetaryMean  \
# segments
# Average Sale Products                 189.908535       1.694013    245.769522
# Costly Products                       170.920424       4.002173   1089.040334
# Fast Moving Average Price Products    105.236082       6.373969    980.425448
# Hardly Any Sale Products              436.716191       1.874954    359.283874
# Infrequent Products                   214.496974       1.190345    167.866961
# Superhit Products                      27.828076      11.330179   1792.174934
#
#                                      GroupSize
# segments
# Average Sale Products                     7850
# Costly Products                           3682
# Fast Moving Average Price Products        3880
# Hardly Any Sale Products                  5398
# Infrequent Products                       7602
# Superhit Products                         3804

# %%
perc = [str('{:.2f}'.format(i/segmentwise['GroupSize'].sum()*100)) + "%" for i in segmentwise['GroupSize']]
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(20, 20)
squarify.plot(sizes = segmentwise['GroupSize'], 
              label = [f'{el[0]} = {el[1]}' for el in zip(segmentwise.index, perc)],
              color = ['yellow', 'limegreen', 'orange', 'red', 'blue', 'coral'],
              alpha = 0.9,text_kwargs={'fontsize':20})
plt.title("RFM Segments",fontsize=26,fontweight="bold")
plt.axis('off')
plt.show()

# %% [markdown]
# #### Observation

# %% [markdown]
# - There is almost equal proportions of average sale and infrequent cheap products. They make approx 50% of inventory
# - Superhit Products and Fast moving average price product account for 25% of inventory
# - Hardly any Sale products account for 1 out of every 6 products in the  inventory

# %%
rfm_segmentation
# Out:
#                                   Recency  Frequency  Monetary  R_Quartile  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38      100          1    120.24           3
# 00088930e925c41fd95ebfe695fd2655      259          1    143.83           2
# 0009406fd7479715e4bef61dd91f2462      250          1    242.10           2
# 000b8f95fcb9e0096488278317764d19       19          2    157.00           4
# 000d9be29b5207b54e86aa1b1ac54872      148          1    218.27           3
# ...                                   ...        ...       ...         ...
# fff6177642830a9a94a0f2cba5e476d1      360          2    285.39           1
# fff81cc3158d2725c0655ab9ba0f712c       30          1     97.89           4
# fff9553ac224cec9d15d49f5a263411f      326          1     43.85           1
# fffdb2d0ec8d6a61f0a0a0db3f25b441       18          5    228.82           4
# fffe9eeff12fcbd74a2f2b007dde0c58      104          1    303.87           3
#
#                                   F_Quartile  M_Quartile RFMScore  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38           1           2      312
# 00088930e925c41fd95ebfe695fd2655           1           2      212
# 0009406fd7479715e4bef61dd91f2462           1           3      213
# 000b8f95fcb9e0096488278317764d19           3           2      432
# 000d9be29b5207b54e86aa1b1ac54872           1           3      313
# ...                                      ...         ...      ...
# fff6177642830a9a94a0f2cba5e476d1           3           3      133
# fff81cc3158d2725c0655ab9ba0f712c           1           2      412
# fff9553ac224cec9d15d49f5a263411f           1           1      111
# fffdb2d0ec8d6a61f0a0a0db3f25b441           4           3      443
# fffe9eeff12fcbd74a2f2b007dde0c58           1           3      313
#
#                                                              segments
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38                  Infrequent Products
# 00088930e925c41fd95ebfe695fd2655                  Infrequent Products
# 0009406fd7479715e4bef61dd91f2462                  Infrequent Products
# 000b8f95fcb9e0096488278317764d19  Fast Moving Average Price Products
# 000d9be29b5207b54e86aa1b1ac54872                Average Sale Products
# ...                                                               ...
# fff6177642830a9a94a0f2cba5e476d1                Average Sale Products
# fff81cc3158d2725c0655ab9ba0f712c                Average Sale Products
# fff9553ac224cec9d15d49f5a263411f             Hardly Any Sale Products
# fffdb2d0ec8d6a61f0a0a0db3f25b441                    Superhit Products
# fffe9eeff12fcbd74a2f2b007dde0c58                Average Sale Products
#
# [32216 rows x 8 columns]

# %%
y= rfm_segmentation.merge(products[['product_id','product_category_name']],on='product_id',how='left')

# %%
y = y.loc[:, ['product_category_name','segments']]

# %%
y
# Out:
#       product_category_name                             segments
# 0                      toys                  Infrequent Products
# 1                      auto                  Infrequent Products
# 2                      toys                  Infrequent Products
# 3                housewares  Fast Moving Average Price Products
# 4                      toys                Average Sale Products
# ...                     ...                                  ...
# 32211                  toys                Average Sale Products
# 32212         health_beauty                Average Sale Products
# 32213                  toys             Hardly Any Sale Products
# 32214                  toys                    Superhit Products
# 32215                  toys                Average Sale Products
#
# [32216 rows x 2 columns]

# %%
pivot = pd.pivot_table(data=y, index=['product_category_name'], columns=['segments'], aggfunc=len,  fill_value=0)

# %%
pivot_sort=pivot.sort_values('Costly Products', ascending=False)

# %%
pivot_sort
# Out:
# segments                   Average Sale Products  Costly Products  \
# product_category_name
# toys                                        5875             2779
# furniture_decor                              154               80
# bed_bath_table                               186               76
# computers_accessories                         94               74
# sports_leisure                               159               71
# ...                                          ...              ...
# fashion_childrens_clothes                      0                0
# home_comfort_2                                 0                0
# fashion_sport                                  1                0
# flowers                                        0                0
# food                                           6                0
#
# segments                   Fast Moving Average Price Products   \
# product_category_name
# toys                                                      2970
# furniture_decor                                             64
# bed_bath_table                                             117
# computers_accessories                                       49
# sports_leisure                                              85
# ...                                                        ...
# fashion_childrens_clothes                                    1
# home_comfort_2                                               0
# fashion_sport                                                0
# flowers                                                      1
# food                                                         4
#
# segments                   Hardly Any Sale Products  Infrequent Products  \
# product_category_name
# toys                                           4128                 5806
# furniture_decor                                 161                  139
# bed_bath_table                                  135                  163
# computers_accessories                            52                   89
# sports_leisure                                  126                  189
# ...                                             ...                  ...
# fashion_childrens_clothes                         0                    0
# home_comfort_2                                    1                    0
# fashion_sport                                     2                    0
# flowers                                           0                    1
# food                                              1                    3
#
# segments                   Superhit Products
# product_category_name
# toys                                    2793
# furniture_decor                           70
# bed_bath_table                           104
# computers_accessories                     53
# sports_leisure                            80
# ...                                      ...
# fashion_childrens_clothes                  0
# home_comfort_2                             0
# fashion_sport                              0
# flowers                                    0
# food                                       6
#
# [70 rows x 6 columns]

# %%
ax = pivot_sort.plot.bar(stacked=True, figsize=(20,10))
ax.set_title('Product Category Sales', fontsize=20)
ax.set_ylim(0,800)
plt.show()

# %% [markdown]
# ##### Observation

# %% [markdown]
# - It is observed that around 20 product categories account for 80% of Overall Sale
# - Close to 40-50 % of furniture decor , bed bath table, sports_leisure, fashion bags and accessories and auto have low frequency or hardly any sale products
# - Flowers, home comfort, fashion childrends clothing , furniture mattress and upholstry , security and services and many more  have hardly any sale

# %% [markdown]
# # Market Basket Analysis

# %%
len(order_items['order_id'].unique())
# Out:
# 98666

# %%
order_items.shape
# Out:
# (112650, 6)

# %%
data = order_items.merge(products[['product_id','product_category_name']], on='product_id', how='inner')

# %%
data.shape
# Out:
# (112650, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               112650 non-null  object
#  1   order_item_id          112650 non-null  int64
#  2   product_id             112650 non-null  object
#  3   seller_id              112650 non-null  object
#  4   price                  112650 non-null  float64
#  5   shipping_charges       112650 non-null  float64
#  6   product_category_name  112650 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.9+ MB

# %%
# Creating a basket for the analysis 
Basket = (data.groupby(['order_id', 'product_category_name'])['order_item_id'].sum().unstack().reset_index().fillna(0).set_index('order_id'))

# %%
Basket
# Out:
# product_category_name             agro_industry_and_commerce  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                         0.0
# 00018f77f2f0320c557190d7a144bdd3                         0.0
# 000229ec398224ef6ca0657da4fc703e                         0.0
# 00024acbcdf0a6daa1e931b038114c75                         0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9                         0.0
# ...                                                      ...
# fffc94f6ce00a00581880bf54a75a037                         0.0
# fffcd46ef2263f404302a634eb57f7eb                         0.0
# fffce4705a9662cd70adb13d4a31832d                         0.0
# fffe18544ffabc95dfada21779c9644f                         0.0
# fffe41c64501cc87c801fd61db3f6244                         0.0
#
# product_category_name             air_conditioning  art  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214               0.0  0.0
# 00018f77f2f0320c557190d7a144bdd3               0.0  0.0
# 000229ec398224ef6ca0657da4fc703e               0.0  0.0
# 00024acbcdf0a6daa1e931b038114c75               0.0  0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9               0.0  0.0
# ...                                            ...  ...
# fffc94f6ce00a00581880bf54a75a037               0.0  0.0
# fffcd46ef2263f404302a634eb57f7eb               0.0  0.0
# fffce4705a9662cd70adb13d4a31832d               0.0  0.0
# fffe18544ffabc95dfada21779c9644f               0.0  0.0
# fffe41c64501cc87c801fd61db3f6244               0.0  0.0
#
# product_category_name             arts_and_craftmanship  audio  auto  baby  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                    0.0    0.0   0.0   0.0
# 00018f77f2f0320c557190d7a144bdd3                    0.0    0.0   0.0   0.0
# 000229ec398224ef6ca0657da4fc703e                    0.0    0.0   0.0   0.0
# 00024acbcdf0a6daa1e931b038114c75                    0.0    0.0   0.0   0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9                    0.0    0.0   0.0   0.0
# ...                                                 ...    ...   ...   ...
# fffc94f6ce00a00581880bf54a75a037                    0.0    0.0   0.0   0.0
# fffcd46ef2263f404302a634eb57f7eb                    0.0    0.0   0.0   0.0
# fffce4705a9662cd70adb13d4a31832d                    0.0    0.0   0.0   0.0
# fffe18544ffabc95dfada21779c9644f                    0.0    0.0   0.0   0.0
# fffe41c64501cc87c801fd61db3f6244                    0.0    0.0   0.0   0.0
#
# product_category_name             bed_bath_table  books_general_interest  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214             0.0                     0.0
# 00018f77f2f0320c557190d7a144bdd3             0.0                     0.0
# 000229ec398224ef6ca0657da4fc703e             0.0                     0.0
# 00024acbcdf0a6daa1e931b038114c75             0.0                     0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9             0.0                     0.0
# ...                                          ...                     ...
# fffc94f6ce00a00581880bf54a75a037             0.0                     0.0
# fffcd46ef2263f404302a634eb57f7eb             0.0                     0.0
# fffce4705a9662cd70adb13d4a31832d             0.0                     0.0
# fffe18544ffabc95dfada21779c9644f             0.0                     0.0
# fffe41c64501cc87c801fd61db3f6244             1.0                     0.0
#
# product_category_name             books_imported  ...  security_and_services  \
# order_id                                          ...
# 00010242fe8c5a6d1ba2dd792cb16214             0.0  ...                    0.0
# 00018f77f2f0320c557190d7a144bdd3             0.0  ...                    0.0
# 000229ec398224ef6ca0657da4fc703e             0.0  ...                    0.0
# 00024acbcdf0a6daa1e931b038114c75             0.0  ...                    0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9             0.0  ...                    0.0
# ...                                          ...  ...                    ...
# fffc94f6ce00a00581880bf54a75a037             0.0  ...                    0.0
# fffcd46ef2263f404302a634eb57f7eb             0.0  ...                    0.0
# fffce4705a9662cd70adb13d4a31832d             0.0  ...                    0.0
# fffe18544ffabc95dfada21779c9644f             0.0  ...                    0.0
# fffe41c64501cc87c801fd61db3f6244             0.0  ...                    0.0
#
# product_category_name             signaling_and_security  small_appliances  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                     0.0               0.0
# 00018f77f2f0320c557190d7a144bdd3                     0.0               0.0
# 000229ec398224ef6ca0657da4fc703e                     0.0               0.0
# 00024acbcdf0a6daa1e931b038114c75                     0.0               0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9                     0.0               0.0
# ...                                                  ...               ...
# fffc94f6ce00a00581880bf54a75a037                     0.0               0.0
# fffcd46ef2263f404302a634eb57f7eb                     0.0               0.0
# fffce4705a9662cd70adb13d4a31832d                     0.0               0.0
# fffe18544ffabc95dfada21779c9644f                     0.0               0.0
# fffe41c64501cc87c801fd61db3f6244                     0.0               0.0
#
# product_category_name             small_appliances_home_oven_and_coffee  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                                    0.0
# 00018f77f2f0320c557190d7a144bdd3                                    0.0
# 000229ec398224ef6ca0657da4fc703e                                    0.0
# 00024acbcdf0a6daa1e931b038114c75                                    0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9                                    0.0
# ...                                                                 ...
# fffc94f6ce00a00581880bf54a75a037                                    0.0
# fffcd46ef2263f404302a634eb57f7eb                                    0.0
# fffce4705a9662cd70adb13d4a31832d                                    0.0
# fffe18544ffabc95dfada21779c9644f                                    0.0
# fffe41c64501cc87c801fd61db3f6244                                    0.0
#
# product_category_name             sports_leisure  stationery  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214             0.0         0.0
# 00018f77f2f0320c557190d7a144bdd3             0.0         0.0
# 000229ec398224ef6ca0657da4fc703e             0.0         0.0
# 00024acbcdf0a6daa1e931b038114c75             0.0         0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9             0.0         0.0
# ...                                          ...         ...
# fffc94f6ce00a00581880bf54a75a037             0.0         0.0
# fffcd46ef2263f404302a634eb57f7eb             0.0         0.0
# fffce4705a9662cd70adb13d4a31832d             0.0         0.0
# fffe18544ffabc95dfada21779c9644f             0.0         0.0
# fffe41c64501cc87c801fd61db3f6244             0.0         0.0
#
# product_category_name             tablets_printing_image  telephony  toys  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                     0.0        0.0   1.0
# 00018f77f2f0320c557190d7a144bdd3                     0.0        0.0   1.0
# 000229ec398224ef6ca0657da4fc703e                     0.0        0.0   1.0
# 00024acbcdf0a6daa1e931b038114c75                     0.0        0.0   1.0
# 00042b26cf59d7ce69dfabb4e55b4fd9                     0.0        0.0   1.0
# ...                                                  ...        ...   ...
# fffc94f6ce00a00581880bf54a75a037                     0.0        0.0   0.0
# fffcd46ef2263f404302a634eb57f7eb                     0.0        0.0   1.0
# fffce4705a9662cd70adb13d4a31832d                     0.0        0.0   1.0
# fffe18544ffabc95dfada21779c9644f                     0.0        0.0   1.0
# fffe41c64501cc87c801fd61db3f6244                     0.0        0.0   0.0
#
# product_category_name             watches_gifts
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214            0.0
# 00018f77f2f0320c557190d7a144bdd3            0.0
# 000229ec398224ef6ca0657da4fc703e            0.0
# 00024acbcdf0a6daa1e931b038114c75            0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9            0.0
# ...                                         ...
# fffc94f6ce00a00581880bf54a75a037            0.0
# fffcd46ef2263f404302a634eb57f7eb            0.0
# fffce4705a9662cd70adb13d4a31832d            0.0
# fffe18544ffabc95dfada21779c9644f            0.0
# fffe41c64501cc87c801fd61db3f6244            0.0
#
# [98666 rows x 70 columns]

# %%
# Converting the values to 0 or 1

def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

Basket_encode = Basket.applymap(encode_units)
Basket_encode
# Out:
# product_category_name             agro_industry_and_commerce  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                           0
# 00018f77f2f0320c557190d7a144bdd3                           0
# 000229ec398224ef6ca0657da4fc703e                           0
# 00024acbcdf0a6daa1e931b038114c75                           0
# 00042b26cf59d7ce69dfabb4e55b4fd9                           0
# ...                                                      ...
# fffc94f6ce00a00581880bf54a75a037                           0
# fffcd46ef2263f404302a634eb57f7eb                           0
# fffce4705a9662cd70adb13d4a31832d                           0
# fffe18544ffabc95dfada21779c9644f                           0
# fffe41c64501cc87c801fd61db3f6244                           0
#
# product_category_name             air_conditioning  art  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                 0    0
# 00018f77f2f0320c557190d7a144bdd3                 0    0
# 000229ec398224ef6ca0657da4fc703e                 0    0
# 00024acbcdf0a6daa1e931b038114c75                 0    0
# 00042b26cf59d7ce69dfabb4e55b4fd9                 0    0
# ...                                            ...  ...
# fffc94f6ce00a00581880bf54a75a037                 0    0
# fffcd46ef2263f404302a634eb57f7eb                 0    0
# fffce4705a9662cd70adb13d4a31832d                 0    0
# fffe18544ffabc95dfada21779c9644f                 0    0
# fffe41c64501cc87c801fd61db3f6244                 0    0
#
# product_category_name             arts_and_craftmanship  audio  auto  baby  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                      0      0     0     0
# 00018f77f2f0320c557190d7a144bdd3                      0      0     0     0
# 000229ec398224ef6ca0657da4fc703e                      0      0     0     0
# 00024acbcdf0a6daa1e931b038114c75                      0      0     0     0
# 00042b26cf59d7ce69dfabb4e55b4fd9                      0      0     0     0
# ...                                                 ...    ...   ...   ...
# fffc94f6ce00a00581880bf54a75a037                      0      0     0     0
# fffcd46ef2263f404302a634eb57f7eb                      0      0     0     0
# fffce4705a9662cd70adb13d4a31832d                      0      0     0     0
# fffe18544ffabc95dfada21779c9644f                      0      0     0     0
# fffe41c64501cc87c801fd61db3f6244                      0      0     0     0
#
# product_category_name             bed_bath_table  books_general_interest  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214               0                       0
# 00018f77f2f0320c557190d7a144bdd3               0                       0
# 000229ec398224ef6ca0657da4fc703e               0                       0
# 00024acbcdf0a6daa1e931b038114c75               0                       0
# 00042b26cf59d7ce69dfabb4e55b4fd9               0                       0
# ...                                          ...                     ...
# fffc94f6ce00a00581880bf54a75a037               0                       0
# fffcd46ef2263f404302a634eb57f7eb               0                       0
# fffce4705a9662cd70adb13d4a31832d               0                       0
# fffe18544ffabc95dfada21779c9644f               0                       0
# fffe41c64501cc87c801fd61db3f6244               1                       0
#
# product_category_name             books_imported  ...  security_and_services  \
# order_id                                          ...
# 00010242fe8c5a6d1ba2dd792cb16214               0  ...                      0
# 00018f77f2f0320c557190d7a144bdd3               0  ...                      0
# 000229ec398224ef6ca0657da4fc703e               0  ...                      0
# 00024acbcdf0a6daa1e931b038114c75               0  ...                      0
# 00042b26cf59d7ce69dfabb4e55b4fd9               0  ...                      0
# ...                                          ...  ...                    ...
# fffc94f6ce00a00581880bf54a75a037               0  ...                      0
# fffcd46ef2263f404302a634eb57f7eb               0  ...                      0
# fffce4705a9662cd70adb13d4a31832d               0  ...                      0
# fffe18544ffabc95dfada21779c9644f               0  ...                      0
# fffe41c64501cc87c801fd61db3f6244               0  ...                      0
#
# product_category_name             signaling_and_security  small_appliances  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                       0                 0
# 00018f77f2f0320c557190d7a144bdd3                       0                 0
# 000229ec398224ef6ca0657da4fc703e                       0                 0
# 00024acbcdf0a6daa1e931b038114c75                       0                 0
# 00042b26cf59d7ce69dfabb4e55b4fd9                       0                 0
# ...                                                  ...               ...
# fffc94f6ce00a00581880bf54a75a037                       0                 0
# fffcd46ef2263f404302a634eb57f7eb                       0                 0
# fffce4705a9662cd70adb13d4a31832d                       0                 0
# fffe18544ffabc95dfada21779c9644f                       0                 0
# fffe41c64501cc87c801fd61db3f6244                       0                 0
#
# product_category_name             small_appliances_home_oven_and_coffee  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                                      0
# 00018f77f2f0320c557190d7a144bdd3                                      0
# 000229ec398224ef6ca0657da4fc703e                                      0
# 00024acbcdf0a6daa1e931b038114c75                                      0
# 00042b26cf59d7ce69dfabb4e55b4fd9                                      0
# ...                                                                 ...
# fffc94f6ce00a00581880bf54a75a037                                      0
# fffcd46ef2263f404302a634eb57f7eb                                      0
# fffce4705a9662cd70adb13d4a31832d                                      0
# fffe18544ffabc95dfada21779c9644f                                      0
# fffe41c64501cc87c801fd61db3f6244                                      0
#
# product_category_name             sports_leisure  stationery  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214               0           0
# 00018f77f2f0320c557190d7a144bdd3               0           0
# 000229ec398224ef6ca0657da4fc703e               0           0
# 00024acbcdf0a6daa1e931b038114c75               0           0
# 00042b26cf59d7ce69dfabb4e55b4fd9               0           0
# ...                                          ...         ...
# fffc94f6ce00a00581880bf54a75a037               0           0
# fffcd46ef2263f404302a634eb57f7eb               0           0
# fffce4705a9662cd70adb13d4a31832d               0           0
# fffe18544ffabc95dfada21779c9644f               0           0
# fffe41c64501cc87c801fd61db3f6244               0           0
#
# product_category_name             tablets_printing_image  telephony  toys  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                       0          0     1
# 00018f77f2f0320c557190d7a144bdd3                       0          0     1
# 000229ec398224ef6ca0657da4fc703e                       0          0     1
# 00024acbcdf0a6daa1e931b038114c75                       0          0     1
# 00042b26cf59d7ce69dfabb4e55b4fd9                       0          0     1
# ...                                                  ...        ...   ...
# fffc94f6ce00a00581880bf54a75a037                       0          0     0
# fffcd46ef2263f404302a634eb57f7eb                       0          0     1
# fffce4705a9662cd70adb13d4a31832d                       0          0     1
# fffe18544ffabc95dfada21779c9644f                       0          0     1
# fffe41c64501cc87c801fd61db3f6244                       0          0     0
#
# product_category_name             watches_gifts
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214              0
# 00018f77f2f0320c557190d7a144bdd3              0
# 000229ec398224ef6ca0657da4fc703e              0
# 00024acbcdf0a6daa1e931b038114c75              0
# 00042b26cf59d7ce69dfabb4e55b4fd9              0
# ...                                         ...
# fffc94f6ce00a00581880bf54a75a037              0
# fffcd46ef2263f404302a634eb57f7eb              0
# fffce4705a9662cd70adb13d4a31832d              0
# fffe18544ffabc95dfada21779c9644f              0
# fffe41c64501cc87c801fd61db3f6244              0
#
# [98666 rows x 70 columns]

# %%
# Filter the Basket with the sum of values having >=2

Basket_encode_filter = Basket_encode[(Basket_encode > 0).sum(axis=1) >=2]
Basket_encode_filter
# Out:
# product_category_name             agro_industry_and_commerce  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e                           0
# 00946f674d880be1f188abc10ad7cf46                           0
# 00bcee890eba57a9767c7b5ca12d3a1b                           0
# 01144cadcf64b6427f0a6580a3033220                           0
# 013a98b3a668bcef05b98898177f6923                           0
# ...                                                      ...
# ff632bc583a94f23c59db4cbaa0ba2ab                           0
# ffa466d3e55f98477b7e0da764df3c6c                           0
# ffb9a9cd00c74c11c24aa30b3d78e03b                           0
# ffc16cecff8dc037f60458f28d1c1ba5                           0
# ffd543c2b60842e148a86870dc60e212                           0
#
# product_category_name             air_conditioning  art  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e                 0    0
# 00946f674d880be1f188abc10ad7cf46                 0    0
# 00bcee890eba57a9767c7b5ca12d3a1b                 0    0
# 01144cadcf64b6427f0a6580a3033220                 0    0
# 013a98b3a668bcef05b98898177f6923                 0    0
# ...                                            ...  ...
# ff632bc583a94f23c59db4cbaa0ba2ab                 0    0
# ffa466d3e55f98477b7e0da764df3c6c                 0    0
# ffb9a9cd00c74c11c24aa30b3d78e03b                 0    0
# ffc16cecff8dc037f60458f28d1c1ba5                 0    0
# ffd543c2b60842e148a86870dc60e212                 0    0
#
# product_category_name             arts_and_craftmanship  audio  auto  baby  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e                      0      0     0     0
# 00946f674d880be1f188abc10ad7cf46                      0      0     0     0
# 00bcee890eba57a9767c7b5ca12d3a1b                      0      0     0     0
# 01144cadcf64b6427f0a6580a3033220                      0      0     0     0
# 013a98b3a668bcef05b98898177f6923                      0      0     0     0
# ...                                                 ...    ...   ...   ...
# ff632bc583a94f23c59db4cbaa0ba2ab                      0      0     0     0
# ffa466d3e55f98477b7e0da764df3c6c                      0      0     0     0
# ffb9a9cd00c74c11c24aa30b3d78e03b                      0      0     0     0
# ffc16cecff8dc037f60458f28d1c1ba5                      0      0     0     0
# ffd543c2b60842e148a86870dc60e212                      0      0     0     0
#
# product_category_name             bed_bath_table  books_general_interest  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e               1                       0
# 00946f674d880be1f188abc10ad7cf46               0                       0
# 00bcee890eba57a9767c7b5ca12d3a1b               0                       0
# 01144cadcf64b6427f0a6580a3033220               0                       0
# 013a98b3a668bcef05b98898177f6923               1                       0
# ...                                          ...                     ...
# ff632bc583a94f23c59db4cbaa0ba2ab               0                       0
# ffa466d3e55f98477b7e0da764df3c6c               0                       0
# ffb9a9cd00c74c11c24aa30b3d78e03b               1                       0
# ffc16cecff8dc037f60458f28d1c1ba5               0                       0
# ffd543c2b60842e148a86870dc60e212               0                       0
#
# product_category_name             books_imported  ...  security_and_services  \
# order_id                                          ...
# 00337fe25a3780b3424d9ad7c5a4b35e               0  ...                      0
# 00946f674d880be1f188abc10ad7cf46               0  ...                      0
# 00bcee890eba57a9767c7b5ca12d3a1b               0  ...                      0
# 01144cadcf64b6427f0a6580a3033220               0  ...                      0
# 013a98b3a668bcef05b98898177f6923               0  ...                      0
# ...                                          ...  ...                    ...
# ff632bc583a94f23c59db4cbaa0ba2ab               0  ...                      0
# ffa466d3e55f98477b7e0da764df3c6c               0  ...                      0
# ffb9a9cd00c74c11c24aa30b3d78e03b               0  ...                      0
# ffc16cecff8dc037f60458f28d1c1ba5               0  ...                      0
# ffd543c2b60842e148a86870dc60e212               0  ...                      0
#
# product_category_name             signaling_and_security  small_appliances  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e                       0                 0
# 00946f674d880be1f188abc10ad7cf46                       0                 0
# 00bcee890eba57a9767c7b5ca12d3a1b                       0                 0
# 01144cadcf64b6427f0a6580a3033220                       0                 0
# 013a98b3a668bcef05b98898177f6923                       0                 0
# ...                                                  ...               ...
# ff632bc583a94f23c59db4cbaa0ba2ab                       0                 0
# ffa466d3e55f98477b7e0da764df3c6c                       0                 0
# ffb9a9cd00c74c11c24aa30b3d78e03b                       0                 0
# ffc16cecff8dc037f60458f28d1c1ba5                       0                 0
# ffd543c2b60842e148a86870dc60e212                       0                 0
#
# product_category_name             small_appliances_home_oven_and_coffee  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e                                      0
# 00946f674d880be1f188abc10ad7cf46                                      0
# 00bcee890eba57a9767c7b5ca12d3a1b                                      0
# 01144cadcf64b6427f0a6580a3033220                                      0
# 013a98b3a668bcef05b98898177f6923                                      0
# ...                                                                 ...
# ff632bc583a94f23c59db4cbaa0ba2ab                                      0
# ffa466d3e55f98477b7e0da764df3c6c                                      0
# ffb9a9cd00c74c11c24aa30b3d78e03b                                      0
# ffc16cecff8dc037f60458f28d1c1ba5                                      0
# ffd543c2b60842e148a86870dc60e212                                      0
#
# product_category_name             sports_leisure  stationery  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e               0           0
# 00946f674d880be1f188abc10ad7cf46               0           0
# 00bcee890eba57a9767c7b5ca12d3a1b               0           0
# 01144cadcf64b6427f0a6580a3033220               0           0
# 013a98b3a668bcef05b98898177f6923               0           0
# ...                                          ...         ...
# ff632bc583a94f23c59db4cbaa0ba2ab               0           0
# ffa466d3e55f98477b7e0da764df3c6c               0           0
# ffb9a9cd00c74c11c24aa30b3d78e03b               0           0
# ffc16cecff8dc037f60458f28d1c1ba5               0           1
# ffd543c2b60842e148a86870dc60e212               0           0
#
# product_category_name             tablets_printing_image  telephony  toys  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e                       0          0     1
# 00946f674d880be1f188abc10ad7cf46                       0          0     1
# 00bcee890eba57a9767c7b5ca12d3a1b                       0          0     1
# 01144cadcf64b6427f0a6580a3033220                       0          0     1
# 013a98b3a668bcef05b98898177f6923                       0          0     1
# ...                                                  ...        ...   ...
# ff632bc583a94f23c59db4cbaa0ba2ab                       0          0     1
# ffa466d3e55f98477b7e0da764df3c6c                       0          0     1
# ffb9a9cd00c74c11c24aa30b3d78e03b                       0          0     1
# ffc16cecff8dc037f60458f28d1c1ba5                       0          0     1
# ffd543c2b60842e148a86870dc60e212                       0          0     1
#
# product_category_name             watches_gifts
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e              0
# 00946f674d880be1f188abc10ad7cf46              0
# 00bcee890eba57a9767c7b5ca12d3a1b              0
# 01144cadcf64b6427f0a6580a3033220              0
# 013a98b3a668bcef05b98898177f6923              0
# ...                                         ...
# ff632bc583a94f23c59db4cbaa0ba2ab              0
# ffa466d3e55f98477b7e0da764df3c6c              0
# ffb9a9cd00c74c11c24aa30b3d78e03b              0
# ffc16cecff8dc037f60458f28d1c1ba5              0
# ffd543c2b60842e148a86870dc60e212              0
#
# [1303 rows x 70 columns]

# %%
frequent_itemsets = apriori(Basket_encode_filter, min_support=0.03,use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
frequent_itemsets["Length"] = frequent_itemsets['itemsets'].apply(lambda x:len(x))

frequent_itemsets
# Out:
# /Users/savprasadarao/opt/anaconda3/lib/python3.9/site-packages/mlxtend/frequent_patterns/fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#      support                          itemsets  Length
# 0   0.971604                            (toys)       1
# 1   0.229470                  (bed_bath_table)       1
# 2   0.225633            (toys, bed_bath_table)       2
# 3   0.127398                 (furniture_decor)       1
# 4   0.119724           (toys, furniture_decor)       2
# 5   0.083653           (computers_accessories)       1
# 6   0.079816     (computers_accessories, toys)       2
# 7   0.067536                   (health_beauty)       1
# 8   0.064467             (toys, health_beauty)       2
# 9   0.057559                   (watches_gifts)       1
# 10  0.056025             (toys, watches_gifts)       2
# 11  0.054490                  (sports_leisure)       1
# 12  0.052955                      (housewares)       1
# 13  0.048350                (housewares, toys)       2
# 14  0.047583            (toys, sports_leisure)       2
# 15  0.041443                    (garden_tools)       1
# 16  0.034536              (garden_tools, toys)       2
# 17  0.033001        (fashion_bags_accessories)       1
# 18  0.032233  (toys, fashion_bags_accessories)       2
# 19  0.031466                            (auto)       1
# 20  0.030698                      (auto, toys)       2

# %% [markdown]
# Setting Lift score to minimum 90% to find the best basket of two products

# %%
rules = association_rules(frequent_itemsets, metric='lift',min_threshold = 0.9).sort_values('lift', ascending=False).reset_index(drop=True)
rules
# Out:
#                    antecedents                 consequents  \
# 0                       (toys)            (bed_bath_table)
# 1             (bed_bath_table)                      (toys)
# 2                       (toys)  (fashion_bags_accessories)
# 3   (fashion_bags_accessories)                      (toys)
# 4                       (auto)                      (toys)
# 5                       (toys)                      (auto)
# 6                       (toys)             (watches_gifts)
# 7              (watches_gifts)                      (toys)
# 8                       (toys)             (health_beauty)
# 9              (health_beauty)                      (toys)
# 10     (computers_accessories)                      (toys)
# 11                      (toys)     (computers_accessories)
# 12                      (toys)           (furniture_decor)
# 13           (furniture_decor)                      (toys)
# 14                      (toys)                (housewares)
# 15                (housewares)                      (toys)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.971604            0.229470  0.225633    0.232227  1.012015
# 1             0.229470            0.971604  0.225633    0.983278  1.012015
# 2             0.971604            0.033001  0.032233    0.033175  1.005290
# 3             0.033001            0.971604  0.032233    0.976744  1.005290
# 4             0.031466            0.971604  0.030698    0.975610  1.004123
# 5             0.971604            0.031466  0.030698    0.031596  1.004123
# 6             0.971604            0.057559  0.056025    0.057662  1.001780
# 7             0.057559            0.971604  0.056025    0.973333  1.001780
# 8             0.971604            0.067536  0.064467    0.066351  0.982443
# 9             0.067536            0.971604  0.064467    0.954545  0.982443
# 10            0.083653            0.971604  0.079816    0.954128  0.982014
# 11            0.971604            0.083653  0.079816    0.082148  0.982014
# 12            0.971604            0.127398  0.119724    0.123223  0.967224
# 13            0.127398            0.971604  0.119724    0.939759  0.967224
# 14            0.971604            0.052955  0.048350    0.049763  0.939728
# 15            0.052955            0.971604  0.048350    0.913043  0.939728
#
#     leverage  conviction
# 0   0.002679    1.003591
# 1   0.002679    1.698081
# 2   0.000170    1.000181
# 3   0.000170    1.221028
# 4   0.000126    1.164236
# 5   0.000126    1.000134
# 6   0.000100    1.000109
# 7   0.000100    1.064850
# 8  -0.001152    0.998730
# 9  -0.001152    0.624712
# 10 -0.001462    0.619033
# 11 -0.001462    0.998361
# 12 -0.004057    0.995238
# 13 -0.004057    0.471374
# 14 -0.003101    0.996641
# 15 -0.003101    0.326554

# %% [markdown]
# ##### Oberservation

# %% [markdown]
# - 97% of customers buying toys are likely to buy bed_bath_table
# - 97% of customers buying toys are likely to buy watches_gifts
# - 97% of customers buying toys are likely to buy fashion_bags_accessories

# %% [markdown]
# Top five products categories in groups of twos are:
# 1. Toys and Bed Bath Table
# 2. Toys and Fashion Bags Accesories
# 3. Toys and Auto
# 4. Toys and Watches Gift
# 5. Toys and Health & Beauty

# %%
# Filter the Basket with the sum of values having >=3

Basket_encode_filter_1 = Basket_encode[(Basket_encode > 0).sum(axis=1) >=3]
Basket_encode_filter_1
# Out:
# product_category_name             agro_industry_and_commerce  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae                           0
# 1c4a92d82c1b0dec18bef12da3fa7756                           0
# 43443d5fff4b94d98df1ad41af13d302                           0
# 5337d26d14027f547caacb7fee230f81                           0
# 91be51c856a90d7efe86cf9d082d6ae3                           0
# a98012aa8c697f2bcff9f8c2183e0f2b                           0
# c6a7876557e3e3e31f229852dfa4f5c3                           0
# d4bec1a24c97bd17be18d77297a0f6a0                           0
# ddb33b0aa1ca6227208f0ca0564f0696                           0
# f1e2b7376f89e974ba81956b133ef935                           0
#
# product_category_name             air_conditioning  art  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae                 0    0
# 1c4a92d82c1b0dec18bef12da3fa7756                 0    0
# 43443d5fff4b94d98df1ad41af13d302                 0    0
# 5337d26d14027f547caacb7fee230f81                 0    0
# 91be51c856a90d7efe86cf9d082d6ae3                 0    0
# a98012aa8c697f2bcff9f8c2183e0f2b                 0    0
# c6a7876557e3e3e31f229852dfa4f5c3                 0    0
# d4bec1a24c97bd17be18d77297a0f6a0                 0    0
# ddb33b0aa1ca6227208f0ca0564f0696                 0    0
# f1e2b7376f89e974ba81956b133ef935                 0    0
#
# product_category_name             arts_and_craftmanship  audio  auto  baby  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae                      0      0     0     0
# 1c4a92d82c1b0dec18bef12da3fa7756                      0      0     0     0
# 43443d5fff4b94d98df1ad41af13d302                      0      0     0     0
# 5337d26d14027f547caacb7fee230f81                      0      0     0     0
# 91be51c856a90d7efe86cf9d082d6ae3                      0      0     0     0
# a98012aa8c697f2bcff9f8c2183e0f2b                      0      0     0     0
# c6a7876557e3e3e31f229852dfa4f5c3                      0      0     0     0
# d4bec1a24c97bd17be18d77297a0f6a0                      0      0     0     0
# ddb33b0aa1ca6227208f0ca0564f0696                      0      0     0     0
# f1e2b7376f89e974ba81956b133ef935                      0      0     0     0
#
# product_category_name             bed_bath_table  books_general_interest  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae               1                       0
# 1c4a92d82c1b0dec18bef12da3fa7756               0                       0
# 43443d5fff4b94d98df1ad41af13d302               1                       0
# 5337d26d14027f547caacb7fee230f81               1                       0
# 91be51c856a90d7efe86cf9d082d6ae3               0                       0
# a98012aa8c697f2bcff9f8c2183e0f2b               0                       0
# c6a7876557e3e3e31f229852dfa4f5c3               0                       0
# d4bec1a24c97bd17be18d77297a0f6a0               0                       0
# ddb33b0aa1ca6227208f0ca0564f0696               1                       0
# f1e2b7376f89e974ba81956b133ef935               1                       0
#
# product_category_name             books_imported  ...  security_and_services  \
# order_id                                          ...
# 0a77b770428bccbea7f9dbf8aec5d6ae               0  ...                      0
# 1c4a92d82c1b0dec18bef12da3fa7756               0  ...                      0
# 43443d5fff4b94d98df1ad41af13d302               0  ...                      0
# 5337d26d14027f547caacb7fee230f81               0  ...                      0
# 91be51c856a90d7efe86cf9d082d6ae3               0  ...                      0
# a98012aa8c697f2bcff9f8c2183e0f2b               0  ...                      0
# c6a7876557e3e3e31f229852dfa4f5c3               0  ...                      0
# d4bec1a24c97bd17be18d77297a0f6a0               0  ...                      0
# ddb33b0aa1ca6227208f0ca0564f0696               0  ...                      0
# f1e2b7376f89e974ba81956b133ef935               0  ...                      0
#
# product_category_name             signaling_and_security  small_appliances  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae                       0                 0
# 1c4a92d82c1b0dec18bef12da3fa7756                       0                 0
# 43443d5fff4b94d98df1ad41af13d302                       0                 0
# 5337d26d14027f547caacb7fee230f81                       0                 0
# 91be51c856a90d7efe86cf9d082d6ae3                       0                 0
# a98012aa8c697f2bcff9f8c2183e0f2b                       0                 0
# c6a7876557e3e3e31f229852dfa4f5c3                       0                 0
# d4bec1a24c97bd17be18d77297a0f6a0                       0                 0
# ddb33b0aa1ca6227208f0ca0564f0696                       0                 0
# f1e2b7376f89e974ba81956b133ef935                       0                 0
#
# product_category_name             small_appliances_home_oven_and_coffee  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae                                      0
# 1c4a92d82c1b0dec18bef12da3fa7756                                      0
# 43443d5fff4b94d98df1ad41af13d302                                      0
# 5337d26d14027f547caacb7fee230f81                                      0
# 91be51c856a90d7efe86cf9d082d6ae3                                      0
# a98012aa8c697f2bcff9f8c2183e0f2b                                      0
# c6a7876557e3e3e31f229852dfa4f5c3                                      0
# d4bec1a24c97bd17be18d77297a0f6a0                                      0
# ddb33b0aa1ca6227208f0ca0564f0696                                      0
# f1e2b7376f89e974ba81956b133ef935                                      0
#
# product_category_name             sports_leisure  stationery  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae               0           0
# 1c4a92d82c1b0dec18bef12da3fa7756               0           0
# 43443d5fff4b94d98df1ad41af13d302               0           0
# 5337d26d14027f547caacb7fee230f81               0           0
# 91be51c856a90d7efe86cf9d082d6ae3               0           0
# a98012aa8c697f2bcff9f8c2183e0f2b               0           0
# c6a7876557e3e3e31f229852dfa4f5c3               0           0
# d4bec1a24c97bd17be18d77297a0f6a0               0           0
# ddb33b0aa1ca6227208f0ca0564f0696               0           0
# f1e2b7376f89e974ba81956b133ef935               0           0
#
# product_category_name             tablets_printing_image  telephony  toys  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae                       0          0     1
# 1c4a92d82c1b0dec18bef12da3fa7756                       0          0     1
# 43443d5fff4b94d98df1ad41af13d302                       0          0     1
# 5337d26d14027f547caacb7fee230f81                       0          0     1
# 91be51c856a90d7efe86cf9d082d6ae3                       0          1     1
# a98012aa8c697f2bcff9f8c2183e0f2b                       0          0     1
# c6a7876557e3e3e31f229852dfa4f5c3                       0          0     1
# d4bec1a24c97bd17be18d77297a0f6a0                       0          0     1
# ddb33b0aa1ca6227208f0ca0564f0696                       0          0     1
# f1e2b7376f89e974ba81956b133ef935                       0          0     1
#
# product_category_name             watches_gifts
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae              0
# 1c4a92d82c1b0dec18bef12da3fa7756              0
# 43443d5fff4b94d98df1ad41af13d302              0
# 5337d26d14027f547caacb7fee230f81              0
# 91be51c856a90d7efe86cf9d082d6ae3              0
# a98012aa8c697f2bcff9f8c2183e0f2b              0
# c6a7876557e3e3e31f229852dfa4f5c3              0
# d4bec1a24c97bd17be18d77297a0f6a0              0
# ddb33b0aa1ca6227208f0ca0564f0696              0
# f1e2b7376f89e974ba81956b133ef935              0
#
# [10 rows x 70 columns]

# %%
frequent_itemsets_1 = apriori(Basket_encode_filter_1, min_support=0.03,use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
frequent_itemsets_1["Length"] = frequent_itemsets_1['itemsets'].apply(lambda x:len(x))

frequent_itemsets_1
# Out:
# /Users/savprasadarao/opt/anaconda3/lib/python3.9/site-packages/mlxtend/frequent_patterns/fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                                          itemsets  Length
# 0       1.0                                            (toys)       1
# 1       0.5                                  (bed_bath_table)       1
# 2       0.5                            (toys, bed_bath_table)       2
# 3       0.4                                 (furniture_decor)       1
# 4       0.4                           (toys, furniture_decor)       2
# 5       0.2                                    (garden_tools)       1
# 6       0.2                           (computers_accessories)       1
# 7       0.2                              (garden_tools, toys)       2
# 8       0.2                     (computers_accessories, toys)       2
# 9       0.2           (toys, furniture_decor, bed_bath_table)       3
# 10      0.2                 (furniture_decor, bed_bath_table)       2
# 11      0.1                (housewares, toys, bed_bath_table)       3
# 12      0.1              (toys, furniture_decor, electronics)       3
# 13      0.1                   (garden_tools, furniture_decor)       2
# 14      0.1             (toys, health_beauty, bed_bath_table)       3
# 15      0.1  (computers_accessories, toys, home_construction)       3
# 16      0.1                                 (toys, telephony)       2
# 17      0.1          (office_furniture, toys, bed_bath_table)       3
# 18      0.1                          (office_furniture, toys)       2
# 19      0.1                                (housewares, toys)       2
# 20      0.1                         (toys, home_construction)       2
# 21      0.1                             (toys, health_beauty)       2
# 22      0.1                     (cine_photo, toys, telephony)       3
# 23      0.1       (computers_accessories, garden_tools, toys)       3
# 24      0.1        (computers_accessories, home_construction)       2
# 25      0.1                               (toys, electronics)       2
# 26      0.1                    (furniture_decor, electronics)       2
# 27      0.1                                      (cine_photo)       1
# 28      0.1             (computers_accessories, garden_tools)       2
# 29      0.1                                (cine_photo, toys)       2
# 30      0.1                           (cine_photo, telephony)       2
# 31      0.1                (office_furniture, bed_bath_table)       2
# 32      0.1                      (housewares, bed_bath_table)       2
# 33      0.1                   (health_beauty, bed_bath_table)       2
# 34      0.1                                       (telephony)       1
# 35      0.1                                (office_furniture)       1
# 36      0.1                                      (housewares)       1
# 37      0.1                               (home_construction)       1
# 38      0.1                                   (health_beauty)       1
# 39      0.1                                     (electronics)       1
# 40      0.1             (garden_tools, furniture_decor, toys)       3

# %% [markdown]
# Choosing the lift with the highest value to determine the best basket of three product

# %%
rules_1 = association_rules(frequent_itemsets_1, metric='lift',min_threshold = 1).sort_values('lift', ascending=False).reset_index(drop=True)
rules_1.head(20)
# Out:
#                       antecedents                    consequents  \
# 0                    (cine_photo)                    (telephony)
# 1                     (telephony)             (cine_photo, toys)
# 2                     (telephony)                   (cine_photo)
# 3              (cine_photo, toys)                    (telephony)
# 4                    (cine_photo)              (toys, telephony)
# 5               (toys, telephony)                   (cine_photo)
# 6   (computers_accessories, toys)            (home_construction)
# 7         (computers_accessories)            (home_construction)
# 8             (home_construction)  (computers_accessories, toys)
# 9         (computers_accessories)      (toys, home_construction)
# 10      (toys, home_construction)        (computers_accessories)
# 11            (home_construction)        (computers_accessories)
# 12                 (garden_tools)  (computers_accessories, toys)
# 13        (computers_accessories)                 (garden_tools)
# 14                  (electronics)        (toys, furniture_decor)
# 15              (furniture_decor)            (toys, electronics)
# 16                  (electronics)              (furniture_decor)
# 17           (garden_tools, toys)        (computers_accessories)
# 18  (computers_accessories, toys)                 (garden_tools)
# 19        (computers_accessories)           (garden_tools, toys)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 0                  0.1                 0.1      0.1        1.00  10.0
# 1                  0.1                 0.1      0.1        1.00  10.0
# 2                  0.1                 0.1      0.1        1.00  10.0
# 3                  0.1                 0.1      0.1        1.00  10.0
# 4                  0.1                 0.1      0.1        1.00  10.0
# 5                  0.1                 0.1      0.1        1.00  10.0
# 6                  0.2                 0.1      0.1        0.50   5.0
# 7                  0.2                 0.1      0.1        0.50   5.0
# 8                  0.1                 0.2      0.1        1.00   5.0
# 9                  0.2                 0.1      0.1        0.50   5.0
# 10                 0.1                 0.2      0.1        1.00   5.0
# 11                 0.1                 0.2      0.1        1.00   5.0
# 12                 0.2                 0.2      0.1        0.50   2.5
# 13                 0.2                 0.2      0.1        0.50   2.5
# 14                 0.1                 0.4      0.1        1.00   2.5
# 15                 0.4                 0.1      0.1        0.25   2.5
# 16                 0.1                 0.4      0.1        1.00   2.5
# 17                 0.2                 0.2      0.1        0.50   2.5
# 18                 0.2                 0.2      0.1        0.50   2.5
# 19                 0.2                 0.2      0.1        0.50   2.5
#
#     leverage  conviction
# 0       0.09         inf
# 1       0.09         inf
# 2       0.09         inf
# 3       0.09         inf
# 4       0.09         inf
# 5       0.09         inf
# 6       0.08         1.8
# 7       0.08         1.8
# 8       0.08         inf
# 9       0.08         1.8
# 10      0.08         inf
# 11      0.08         inf
# 12      0.06         1.6
# 13      0.06         1.6
# 14      0.06         inf
# 15      0.06         1.2
# 16      0.06         inf
# 17      0.06         1.6
# 18      0.06         1.6
# 19      0.06         1.6

# %% [markdown]
# ##### Observations:

# %% [markdown]
# Top five products categories in groups of threes are:
# 1. Toys, Cine photos and Telephony
# 2. Toys, Home Construction and Computer Accessories
# 3. Toys, Garden Tools and Computer Accessories
# 4. Toys Furniture Decor and Electronics
# 5. Toys, Furniture Decor and Health and Beauty
